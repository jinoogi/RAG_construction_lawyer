# %%
import pickle
from pprint import pprint

# pickle 파일 불러오기
with open("crawl_result.pkl", "rb") as file:
    main_laws, sub_laws = pickle.load(file)

# 데이터를 출력하여 쉽게 확인 (Jupyter Notebook에서 실행)
pprint(main_laws)
pprint(sub_laws)
# Out:
# [[{'조항명': '제1조(목적)',
#    '타입': '본문',
#    '하위조항들의uuid': [UUID('3fdde658-90d6-433b-8564-379ac4c161ab')]},
#   '제1조(목적)\n'
#   '이 훈령은\n'
#   '「산업안전보건법」\n'
#   ',\n'
#   '「중대재해 처벌 등에 관한 법률」\n'
#   '(단, 중대시민재해에 관한 사항은 제외한다. 이하 같다),\n'
#   '「산업재해보상보험법」\n'
#   '(단,\n'
#   '제111조의2 및 제127조제3항제3호\n'
#   '에 관한 사항에 한한다. 이하 같다) 및\n'
#   '「진폐의 예방과 진폐근로자의 보호 등에 관한 법률」\n'
#   '을 담당하는 근로감독관의 직무집행에 필요한 사항을 규정함을 목적으로 한다.'],
#  [{'조항명': '제2조(근로감독관의 직무)', '타입': '본문', '하위조항들의uuid': []},
#   '제2조(근로감독관의 직무)\n'
#   '근로감독관(이하 "감독관"이라 한다)은 다음 각 호의 직무를 수행한다.\n'
#   '1.\n'
#   '「산업안전보건법」\n'
#   '(이하 "산안법"이라 한다),\n'
#   '「중대재해 처벌 등에 관한 법률」\n'
#   '(이하 "중처법"이라 한다),\n'
#   '「산업재해보상보험법」\n'
#   '(이하 "산재보험법"이라 한다) 및\n'
#   '「진폐의 예방과 진폐근로자의 보호 등에 관한 법률」\n'
#   '(이하 "진폐법"이라 한다)의 집행을 위한 직무\n'
#   '2. 산안법, 중처법, 산재보험법 및 진폐법(이하 "법령"이라 한다) 위반의 죄에 관한 수사 등 사법경찰관의 직무\n'
#   '3. 재해발생 상황 파악, 재해발생 원인조사 및 조치\n'
#   '4. 법령에 대한 질의응답 및 상담\n'
#   '5. 그 밖에 법령의 운영과 관련하여 고용노동부장관(이하 "장관"이라 한다)이 지시하는 업무'],
# ...
